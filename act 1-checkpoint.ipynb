# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io.wavfile import write

# Parameters for the sound wave
duration = 10     # Duration of the sound in seconds
frequency = 214  # Frequency of the sine wave in Hz (A4 note)
sampling_rate = 12240  # Samples per second
t = np.linspace(0, duration, int(sampling_rate * duration), False)

# Generate the sound wave
amplitude = 0.10
sound_wave = amplitude * np.sin(2 * np.pi * frequency * t)

# plot the sound using sounddevice
plt.figure()
plt.plot(t, sound_wave)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Marve Simple Soundwave')
plt.grid()
plt.show()

# Display an interactive audio player
audio_widget = Audio(sine_wave, rate=sampling_rate)
display(audio_widget)

# Save the sound wave as a WAV file
write('output_sound.wav', sampling_freq, sound_wave.astype(np.float32))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 25
#      22 plt.show()
#      24 # Display an interactive audio player
# ---> 25 audio_widget = Audio(sine_wave, rate=sampling_rate)
#      26 display(audio_widget)
#      28 # Save the sound wave as a WAV file
#
# NameError: name 'Audio' is not defined
